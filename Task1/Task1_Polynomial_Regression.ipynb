# %% [markdown]
# <a href="https://colab.research.google.com/github/andreas31603/MechaineLearningTasks/blob/main/Task1/Task1_Polynomial_Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Polynomial Regression

# %% [markdown]
# ## Importing the libraries

# %%
# Untuk mengabilkan dataset dari google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression

# %% [markdown]
# ## Importing the dataset

# %%
dataset = pd.read_csv('/content/drive/MyDrive/Dataset/Position_Salaries.csv')
X = dataset.iloc[:, 1:2].values  # Using 'Level' as the independent variable
y = dataset.iloc[:, -1].values   # Using 'Salary' as the dependent variable

# %% [markdown]
# ## Training the Linear Regression model on the whole dataset

# %%
# 2. Training the Linear Regression model on the whole dataset
lin_reg = LinearRegression()
lin_reg.fit(X, y)
# Out:
# LinearRegression()

# %% [markdown]
# ## Training the Polynomial Regression model on the whole dataset

# %%
# 3. Training the Polynomial Regression model on the whole dataset
poly_reg = PolynomialFeatures(degree=4)  # Using degree 4 as an example
X_poly = poly_reg.fit_transform(X)
lin_reg_poly = LinearRegression()
lin_reg_poly.fit(X_poly, y)
# Out:
# LinearRegression()

# %% [markdown]
# ## Visualising the Linear Regression results

# %%
# 4. Visualizing the Linear Regression results
plt.scatter(X, y, color='red')
plt.plot(X, lin_reg.predict(X), color='blue')
plt.title('Salary vs Level (Linear Regression)')
plt.xlabel('Position Level')
plt.ylabel('Salary')
plt.show()

# %% [markdown]
# ## Visualising the Polynomial Regression results

# %%
# 5. Visualizing the Polynomial Regression results
X_grid = np.arange(min(X), max(X), 0.1)  # For smoother curve
X_grid = X_grid.reshape((len(X_grid), 1))
plt.scatter(X, y, color='red')
plt.plot(X_grid, lin_reg_poly.predict(poly_reg.fit_transform(X_grid)), color='blue')
plt.title('Salary vs Level (Polynomial Regression)')
plt.xlabel('Position Level')
plt.ylabel('Salary')
plt.show()
# Out:
# <ipython-input-7-d1c1576aa93d>:2: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   X_grid = np.arange(min(X), max(X), 0.1)  # For smoother curve

# %% [markdown]
# ## Predicting a new result with Linear Regression

# %%
# 6. Predicting a new result with Linear Regression
linear_prediction = lin_reg.predict([[6.5]])
print(f"Linear Regression prediction for level 6.5: {linear_prediction}")
# Out:
# Linear Regression prediction for level 6.5: [330378.78787879]

# %% [markdown]
# ## Predicting a new result with Polynomial Regression

# %%
# 7. Predicting a new result with Polynomial Regression
poly_prediction = lin_reg_poly.predict(poly_reg.fit_transform([[6.5]]))
print(f"Polynomial Regression prediction for level 6.5: {poly_prediction}")
# Out:
# Polynomial Regression prediction for level 6.5: [158862.45265155]
